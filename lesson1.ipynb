# %% [markdown]
# <div style="font-size:32px; font-weight:bold; color:green; font-family:Arial;">
#   &#129514;  Lesson 1 : Exploring the Dataset
# </div>

# %% [markdown]
#  <h2 style="color:#1565C0">📦 Step 1: Import Libraries</h2>

# %%
import pandas as pd # for data loading and manipulation
import numpy as np  # for numerical operations
import matplotlib.pyplot as plt # for plotting
import seaborn as sns # for statistical data visualization

# %% [markdown]
# ✅ These are essential tools for data science in Python.
# ✅ They help us clean, analyze, and visualize the dataset.

# %% [markdown]
#  <h2 style="color:#6A1B9A">📂 Step 2: Load the Dataset</h2>

# %%
Data = pd.read_csv('student_exam.csv') # read the CSV file into a DataFrame

# %% [markdown]
# ✅ This reads in the student data so we can work with it programmatically.

# %% [markdown]
#  <h2 style="color:#C62828">🔍 Step 3: Initial Inspection</h2>

# %%
Data.head()  # show the first 5 rows to get a sense of the columns and values
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # 📚 Dataset Attributes Overview
#
# This reference explains the features found in  `student_exam.csv` .
# These features are used in predictive modeling, such as identifying factors that influence student exam success.
#
# ---
#
# ## 🏫 Demographics & Background
#
# | Feature        | Description                                                                 |
# |----------------|------------------------------------------------------------------------------|
# | **school**     | Student's school (binary): `"GP"` = Gabriel Pereira, `"MS"` = Mousinho da Silveira |
# | **sex**        | Student's sex (binary): `"F"` = female, `"M"` = male                        |
# | **age**        | Student's age (numeric): 15 to 22                                           |
# | **address**    | Home address type (binary): `"U"` = urban, `"R"` = rural                    |
# | **famsize**    | Family size (binary): `"LE3"` = ≤3 members, `"GT3"` = >3 members            |
# | **Pstatus**    | Parent's cohabitation status (binary): `"T"` = together, `"A"` = apart      |
#
# ---
#
# ## 🎓 Parental & Guardian Info
#
# | Feature   | Description                                                                 |
# |-----------|------------------------------------------------------------------------------|
# | **Medu**  | Mother's education (0 = none, 4 = higher education)                         |
# | **Fedu**  | Father's education (same scale as Medu)                                     |
# | **Mjob**  | Mother's job: `"teacher"`, `"health"`, `"services"`, `"at_home"`, `"other"` |
# | **Fjob**  | Father's job: same as Mjob                                                  |
# | **guardian** | Student’s legal guardian: `"mother"`, `"father"`, `"other"`              |
#
# ---
#
# ## 📍 School & Academic Information
#
# | Feature     | Description                                                                 |
# |-------------|------------------------------------------------------------------------------|
# | **reason**  | Reason for choosing school: `"home"`, `"reputation"`, `"course"`, `"other"` |
# | **traveltime** | Time from home to school (1 = <15 min, 4 = >1 hour)                     |
# | **studytime**  | Weekly study time (1 = <2 hrs, 4 = >10 hrs)                             |
# | **failures**   | Past class failures (0–4; 4 = 3 or more failures)                       |
# | **schoolsup**  | Extra school support (binary: `yes` or `no`)                            |
# | **famsup**     | Family support (binary: `yes` or `no`)                                  |
# | **paid**       | Paid tutoring in subject (binary: `yes` or `no`)                        |
# | **activities** | Participation in extracurriculars (binary: `yes` or `no`)               |
# | **nursery**    | Attended nursery school (binary: `yes` or `no`)                         |
# | **higher**     | Aspires to higher education (binary: `yes` or `no`)                     |
# | **internet**   | Internet access at home (binary: `yes` or `no`)                         |
# | **romantic**   | Romantic relationship status (binary: `yes` or `no`)                    |
#
# ---
#
# ## 🧠 Personal & Social Attributes
#
# | Feature     | Description                                                  |
# |-------------|--------------------------------------------------------------|
# | **famrel**  | Family relationship quality (1 = very bad to 5 = excellent) |
# | **freetime**| Free time after school (1 = low to 5 = high)                |
# | **goout**   | Frequency of going out with friends (1 = low to 5 = high)   |
# | **Dalc**    | Workday alcohol consumption (1 = low to 5 = high)           |
# | **Walc**    | Weekend alcohol consumption (1 = low to 5 = high)           |
# | **health**  | Current health status (1 = very bad to 5 = very good)       |
# | **absences**| Number of school absences (0 to 93)                         |
#
# ---
#
# ## 🧪 Academic Grades (Course Specific)
#
# | Feature | Description                                 |
# |---------|---------------------------------------------|
# | **G1**  | First period grade (0 to 20)                |
# | **G2**  | Second period grade (0 to 20)               |
# | **G3**  | Final grade (0 to 20) → 🎯 Target variable   |
#
# ---

# %%
Data.shape # display the (rows, columns) tuple to know size of dataset
# Out:
# (1044, 33)

# %%
Data.info() # concise summary: column names, non-null counts, dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %%
Data.isnull().sum()  # count missing values per column
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
Data.describe() # basic statistics for numeric columns (mean, std, min, max…)
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %% [markdown]
# ✅ These commands help us understand:
# - How big the dataset is
# - What data types we’re working with
# - If any values are missing
# - How variables are distributed

# %% [markdown]
# <h2 style="color:#00796B">📊 Step 4:  Exploratory Data Analysis(EDA) </h2>

# %%
custom_palette = {
    'F/yes': '#e91e63',   # female & in a romantic relationship
    'F/no':  '#f8bbd0',   # female & not in a romantic relationship
    'M/yes': '#2196f3',   # male & in a romantic relationship
    'M/no':  '#90caf9'    # male & not in a romantic relationship
}

Data['Gender_and_Romantic Relationship'] = Data['sex'] + "/" + Data['romantic']

sns.countplot(data=Data,x='studytime' , hue = "Gender_and_Romantic Relationship" , palette = custom_palette )
plt.ylabel('Number of Students')
plt.xlabel('Study Hours')
plt.title('Study Time by Gender and Romantic Relationship')
plt.show()

# %%
# List of numerical features to visualize
num_features = [
    'G1', 'G2', 'G3',         # Grades
    'age', 'studytime', 'traveltime', 'failures', 'absences',
    'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health'
]

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
plt.figure(figsize=(16, 18))

# Loop through features and plot
for i, feature in enumerate(num_features):
    plt.subplot(5, 3, i + 1)
    Data[feature].hist(bins=15, edgecolor='black')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Understanding the Histograms in EDA
#
# Histograms help us visualize the **distribution** of numerical data and uncover useful patterns, such as skewness, modality, or the presence of outliers. Below is a breakdown of what each histogram reveals about students’ behavior, lifestyle, and academic performance:
#
# ---
#
# ### 🎓 Academic Performance
#
# - **G1, G2, G3**:
#   These histograms show how students are distributed across different grade levels. A **left-skewed** distribution might indicate grade inflation, while a **right-skewed** pattern may reveal underperformance.
#
# ---
#
# ### 🧠 Effort & Commitment
#
# - **studytime**:
#   Helps us see how many students study less than 2 hours vs. more than 10 hours per week. Can highlight motivation levels or time constraints.
#
# - **traveltime**:
#   Shows how far students live from school. Peaks at lower times may mean most students live nearby.
#
# - **failures**:
#   Reveals how common academic struggles are. A spike at 0 indicates many students haven't failed, but outliers (3 or more) may need additional support.
#
# - **absences**:
#   Tracks school attendance. Can uncover chronic absenteeism or discipline issues affecting learning.
#
# ---
#
# ### 👨‍👩‍👧‍👦 Family & Social Factors
#
# - **famrel**:
#   Distribution of family relationship quality. A central peak around 4–5 implies mostly good relations, which might correlate positively with performance.
#
# - **freetime**, **goout**:
#   Show how students balance social life and school. Useful for exploring whether excessive leisure affects grades.
#
# ---
#
# ### 🍷 Lifestyle Habits
#
# - **Dalc**, **Walc**:
#   Important for understanding alcohol consumption patterns. Spikes at lower levels are ideal, but higher peaks during weekends (`Walc`) may indicate behavioral trends.
#
# ---
#
# ### ❤️ Health & Age
#
# - **health**:
#   Self-assessed health levels; usually centered unless specific issues dominate.
#
# - **age**:
#   Should follow a bell-shaped distribution based on school-age norms (mostly 15–19). Outliers could point to non-traditional learners or repeating students.
#
# ---
#
# ## 🔍 Insights & Use Cases
#
# - Identify **at-risk students** using combinations of high absences, low grades, and low studytime.
# - Design **interventions** targeted at lifestyle or academic behavior extremes.
# - Tailor **curriculum plans** around common student profiles revealed by the histograms.
#
# ---

# %% [markdown]
# ✅ Visuals help uncover patterns:
# - Do students in relationships study more or less?
# - Are there gender differences in study behavior?

# %% [markdown]
#  <h2 style="color:#5D4037">🔗 Step 5: Correlation Matrix</h2>

# %%
#   c) Correlation Matrix (numeric-only)
corr_matrix = Data.corr(numeric_only=True)
plt.figure(figsize=(20, 8))
plt.gcf().set_facecolor('#FFFDD0') 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix without Categorical Features')
plt.show()

# %% [markdown]
# ✅ This reveals:
# - Which features are strongly related to final grade (`G3`)
# - Useful inputs for later modeling (e.g. `G1`, `G2`)

# %% [markdown]
#  <h2 style="color:#00695C">🧠 What You Should Learn</h2>

# %% [markdown]
# ✅ How to load and inspect a dataset
# ✅ How to identify missing values and column types
# ✅ How to use visualization to detect patterns
# ✅ How to compute and interpret feature correlations
# ✅ How to prepare insights before modeling

# %% [markdown]
#  <h2 style="color:#00695C">🎯 Challenges For You :  </h2>

# %% [markdown]
# Try these exploration tasks:
#
# 📊 1. Compare study time across parental education levels
# 🧍‍♂️ 2. Create a bar chart of pass/fail rates by gender
# 📈 3. Add a new feature: average grade = (G1 + G2)/2
# 🔍 4. Visualize absences for students who failed (G3 < 10)
# 🧪 5. Plot count of students with 3+ failures
